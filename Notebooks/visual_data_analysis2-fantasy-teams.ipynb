# %% [markdown]
# # World Football Data - Visual Data Analysis
#
# In this project, we will perform fundamental analysis on the European Soccer Leagues.
#
# This Noteboook contains the Formation and Team Plotting each Fantasy Team per League

# %% [markdown]
# ## Import Libraries

# %%
# Imports for soccer plotting
from highlight_text import ax_text,fig_text
import matplotlib.pyplot as plt
import mplsoccer
from mplsoccer import Pitch, add_image
import numpy as np
from PIL import Image
from urllib.request import urlopen
import mplcursors

# %% [markdown]
# ## EPL - Plot of best players on soccer pitch

# %%
# SETTING UP THE AXES plotting to make sure background change worked
background = 'Grey'
fig, ax = plt.subplots(figsize=(12,10))
ax.axis('off')
fig.set_facecolor(background)

# %%
# Setting up image plots
# load the image
# Cristiano Ronaldo
image_url = 'https://i.imgur.com/Nt4zSjK.png'
ronaldo_image = Image.open(urlopen(image_url))
# Harry Kane 
image_url = 'https://i.imgur.com/9EL22vy.png'
kane_image = Image.open(urlopen(image_url))
# Kevin De Bruyne
IMAGE_URL = 'https://i.imgur.com/9Res3Ir.png'
debruyne_image = Image.open(urlopen(IMAGE_URL))
# Sadio Mané
IMAGE_URL = 'https://i.imgur.com/ZCzXSG8.png'
mane_image = Image.open(urlopen(IMAGE_URL))
# Mohamed Salah 
IMAGE_URL = 'https://i.imgur.com/dzYL0I6.png'
salah_image = Image.open(urlopen(IMAGE_URL))
# Heung Min Son
IMAGE_URL = 'https://i.imgur.com/uEmIJXY.png'
son_image = Image.open(urlopen(IMAGE_URL))
# Virgil van Dijk
IMAGE_URL = 'https://i.imgur.com/ps71Aso.png'
vandijk_image = Image.open(urlopen(IMAGE_URL))
# Trent Alexander-Arnold
IMAGE_URL = 'https://i.imgur.com/ELUWTrD.png'
alexanderarnold_image = Image.open(urlopen(IMAGE_URL))
# Rúben Dias
IMAGE_URL = 'https://i.imgur.com/erav1lL.png'
dias_image = Image.open(urlopen(IMAGE_URL))
# Andrew Robertson
IMAGE_URL = 'https://i.imgur.com/mVI0BWo.png'
robertson_image = Image.open(urlopen(IMAGE_URL))
# Alisson
IMAGE_URL = 'https://i.imgur.com/aEkHvgB.png'
alisson_image = Image.open(urlopen(IMAGE_URL))
# League Image
IMAGE_URL = 'https://assets.turbologo.com/blog/en/2020/01/19084654/Premier-League-logo.png'
premierleague_image = Image.open(urlopen(IMAGE_URL))

# %%
#SETTING UP THE MPL AXIS FOR THE Soccer pitch
pitch = Pitch(pitch_color='grass', line_color='white', stripe=True, linewidth=3)

fig, ax = pitch.draw(figsize=(12,10))

# Strikers
ax.text(108, -1, "ST", weight='bold', size=20)
# Cristiano Ronaldo
ax_image = add_image(ronaldo_image, fig, left=0.825, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(100, 61.5, "Cristiano Ronaldo", weight='bold', size=12)
ax.text(99.2, 63.5, "Manchester United", weight='bold', size=12)
ax.text(104, 65.5, "Rating: 91", weight='bold', size=12)

# Harry Kane
ax_image = add_image(kane_image, fig, left=0.825, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(103.5, 35, "Harry Kane", weight='bold', size=12)
ax.text(104, 37, "Tottenham", weight='bold', size=12)
ax.text(104.2, 39, "Rating: 90", weight='bold', size=12)

# Midfielders
ax.text(78, -1, "MID", weight='bold', size=20)
# Kevin De Bruyne
ax_image = add_image(debruyne_image, fig, left=0.685, bottom=0.67, width=0.1, alpha=1, interpolation='hanning')
ax.text(82.5, 20, "Kevin De Bruyne", weight='bold', size=12)
ax.text(82.5, 22, "Manchester City", weight='bold', size=12)
ax.text(85.5, 24, "Rating: 91", weight='bold', size=12)

# Sadio Mané
ax_image = add_image(mane_image, fig, left=0.53, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(64.5, 35, "Sadio Mane", weight='bold', size=12)
ax.text(66, 37, "Liverpool", weight='bold', size=12)
ax.text(65.7, 39, "Rating: 89", weight='bold', size=12)

# Mohamed Salah
ax_image = add_image(salah_image, fig, left=0.53, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(62, 61.5, "Mohamed Salah", weight='bold', size=12)
ax.text(66, 63.5, "Liverpool", weight='bold', size=12)
ax.text(65.3, 65.5, "Rating: 89", weight='bold', size=12)

# Heung Min Son
ax_image = add_image(son_image, fig, left=0.685, bottom=0.16, width=0.1, alpha=1, interpolation='hanning')
ax.text(83, 75.5, "Heung Min Son", weight='bold', size=12)
ax.text(85.5, 77.5, "Tottenham", weight='bold', size=12)
ax.text(85.5, 79.5, "Rating: 89", weight='bold', size=12)

# Defenders
ax.text(36, -1, "DEF", weight='bold', size=20)
# Virgil van Dijk
ax_image = add_image(vandijk_image, fig, left=0.37, bottom=0.67, width=0.1, alpha=1, interpolation='hanning')
ax.text(42, 20, "Virgil van Dijk", weight='bold', size=12)
ax.text(45, 22, "Liverpool", weight='bold', size=12)
ax.text(44.5, 24, "Rating: 89", weight='bold', size=12)

# Trent Alexander-Arnold
ax_image = add_image(alexanderarnold_image, fig, left=0.22, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(17.5, 35, "Trent Alexander-Arnold", weight='bold', size=12)
ax.text(25, 37, "Liverpool", weight='bold', size=12)
ax.text(24.5, 39, "Rating: 87", weight='bold', size=12)

# Rúben Dias
ax_image = add_image(dias_image, fig, left=0.22, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(24, 61.5, "Ruben Dias", weight='bold', size=12)
ax.text(21.5, 63.5, "Manchester City", weight='bold', size=12)
ax.text(24.5, 65.5, "Rating: 87", weight='bold', size=12)

# Andrew Robertson
ax_image = add_image(robertson_image, fig, left=0.37, bottom=0.16, width=0.1, alpha=1, interpolation='hanning')
ax.text(40, 75.5, "Andrew Robertson", weight='bold', size=12)
ax.text(44.5, 77.5, "Liverpool", weight='bold', size=12)
ax.text(44.1, 79.5, "Rating: 87", weight='bold', size=12)

# GoalKeeper
ax.text(6, -1, "GK", weight='bold', size=20)
# Alisson
ax_image = add_image(alisson_image, fig, left=0.05, bottom=0.40, width=0.1, alpha=1, interpolation='hanning')
ax.text(4, 49.5, "Alisson", weight='bold', size=12)
ax.text(3, 51.5, "Liverpool", weight='bold', size=12)
ax.text(2.5, 53.5, "Rating: 89", weight='bold', size=12)

# League Image Next to Title
ax_image = add_image(premierleague_image, fig, left=0.05, bottom=0.87, width=0.12, interpolation='hanning')

title = fig.suptitle("Premier League Best Fantasy Team", x=0.57, y=0.9, va='center', ha='center', fontsize=38)

fig.set_facecolor(background)

# %% [markdown]
# ## Ligue1 - Plot of best players on soccer pitch

# %%
# SETTING UP THE AXES plotting to make sure background change worked
background = 'Grey'
fig, ax = plt.subplots(figsize=(12,10))
ax.axis('off')
fig.set_facecolor(background)

# %%
# Setting up image plots
# load the image
# Neymar Jr
image_url = 'https://i.imgur.com/qxJUsH0.png'
neymar_image = Image.open(urlopen(image_url))
# Kylian Mbappé
image_url = 'https://i.imgur.com/n9Dcsg7.png'
mbappe_image = Image.open(urlopen(image_url))
# Lionel Messi
IMAGE_URL = 'https://i.imgur.com/xUafiLm.png'
messi_image = Image.open(urlopen(IMAGE_URL))
# Marco Verratti
IMAGE_URL = 'https://i.imgur.com/6dvDvBX.png'
verratti_image = Image.open(urlopen(IMAGE_URL))
# Ángel Di María 
IMAGE_URL = 'https://i.imgur.com/xYWRiLi.png'
dimaria_image = Image.open(urlopen(IMAGE_URL))
# Georginio Wijnaldum
IMAGE_URL = 'https://i.imgur.com/LbsdsBF.png'
wijnaldum_image = Image.open(urlopen(IMAGE_URL))
# Sergio Ramos García
IMAGE_URL = 'https://i.imgur.com/zxjgW8C.png'
sramosgarcia_image = Image.open(urlopen(IMAGE_URL))
# Marquinhos
IMAGE_URL = 'https://i.imgur.com/ZEerrKK.png'
marquinhos_image = Image.open(urlopen(IMAGE_URL))
# Achraf Hakimi
IMAGE_URL = 'https://i.imgur.com/JkYRxzh.png'
hakimi_image = Image.open(urlopen(IMAGE_URL))
# Presnel Kimpembe
IMAGE_URL = 'https://i.imgur.com/7bu2yva.png'
kimpembe_image = Image.open(urlopen(IMAGE_URL))
# Gianluigi Donnarumma 
IMAGE_URL = 'https://i.imgur.com/Oay3Ze8.png'
donnarumma_image = Image.open(urlopen(IMAGE_URL))
# League Image
IMAGE_URL = 'https://4.bp.blogspot.com/-4LwsXxqR5wY/Xu9eHQlhwuI/AAAAAAACdf8/6uIxrhfUHnYpXzfqMwwkq--mOq7WxlNgQCNcBGAsYHQ/s550/ligue-1-logo-%25284%2529.png'
ligue1_image = Image.open(urlopen(IMAGE_URL))

# %%
#SETTING UP THE MPL AXIS FOR THE Soccer pitch
pitch = Pitch(pitch_color='grass', line_color='white', stripe=True, linewidth=3)

fig, ax = pitch.draw(figsize=(12,10))

# Strikers
ax.text(108, -1, "ST", weight='bold', size=20)
# Neymar Jr
ax_image = add_image(neymar_image, fig, left=0.825, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(103.5, 60.5, "Neymar Jr", weight='bold', size=12)
ax.text(107, 62.5, "PSG", weight='bold', size=12)
ax.text(104, 64.5, "Rating: 93", weight='bold', size=12)

# Kylian Mbappé
ax_image = add_image(mbappe_image, fig, left=0.825, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(101.5, 34, "Kylian Mbappe", weight='bold', size=12)
ax.text(107, 36, "PSG", weight='bold', size=12)
ax.text(104.2, 38, "Rating: 86", weight='bold', size=12)

# Midfielders
ax.text(78, -1, "MID", weight='bold', size=20)
# Lionel Messi
ax_image = add_image(messi_image, fig, left=0.685, bottom=0.67, width=0.1, alpha=1, interpolation='hanning')
ax.text(84.5, 19, "Lionel Messi", weight='bold', size=12)
ax.text(88.5, 21, "PSG", weight='bold', size=12)
ax.text(85.5, 23, "Rating: 93", weight='bold', size=12)

# Marco Verratti
ax_image = add_image(verratti_image, fig, left=0.53, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(63, 34, "Marco Verratti", weight='bold', size=12)
ax.text(68.5, 36, "PSG", weight='bold', size=12)
ax.text(65.3, 38, "Rating: 87", weight='bold', size=12)

# Ángel Di María
ax_image = add_image(dimaria_image, fig, left=0.53, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(62.7, 60.5, "Angel Di Maria", weight='bold', size=12)
ax.text(68.5, 62.5, "PSG", weight='bold', size=12)
ax.text(65.3, 64.5, "Rating: 87", weight='bold', size=12)

# Georginio Wijnaldum
ax_image = add_image(wijnaldum_image, fig, left=0.685, bottom=0.16, width=0.1, alpha=1, interpolation='hanning')
ax.text(80, 75, "Georginio Wijnaldum", weight='bold', size=12)
ax.text(88.5, 77, "PSG", weight='bold', size=12)
ax.text(85.5, 79, "Rating: 84", weight='bold', size=12)

# Defenders
ax.text(36, -1, "DEF", weight='bold', size=20)
# Sergio Ramos García
ax_image = add_image(sramosgarcia_image, fig, left=0.37, bottom=0.67, width=0.1, alpha=1, interpolation='hanning')
ax.text(38.5, 19, "Sergio Ramos Garcia", weight='bold', size=12)
ax.text(47.5, 21, "PSG", weight='bold', size=12)
ax.text(44.5, 23, "Rating: 88", weight='bold', size=12)

# Marquinhos
ax_image = add_image(marquinhos_image, fig, left=0.22, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(23.5, 34, "Marquinhos", weight='bold', size=12)
ax.text(27.5, 36, "PSG", weight='bold', size=12)
ax.text(24.5, 38, "Rating: 87", weight='bold', size=12)

# Achraf Hakimi
ax_image = add_image(hakimi_image, fig, left=0.22, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(22.3, 60.5, "Achraf Hakimi", weight='bold', size=12)
ax.text(27.5, 62.5, "PSG", weight='bold', size=12)
ax.text(24.5, 64.5, "Rating: 85", weight='bold', size=12)

# Presnel Kimpembe
ax_image = add_image(kimpembe_image, fig, left=0.37, bottom=0.16, width=0.1, alpha=1, interpolation='hanning')
ax.text(40, 75, "Presnel Kimpembe", weight='bold', size=12)
ax.text(47.5, 77, "PSG", weight='bold', size=12)
ax.text(44.1, 79, "Rating: 83", weight='bold', size=12)

# GoalKeeper
ax.text(6, -1, "GK", weight='bold', size=20)
# Gianluigi Donnarumma
ax_image = add_image(donnarumma_image, fig, left=0.05, bottom=0.40, width=0.1, alpha=1, interpolation='hanning')
ax.text(-3.5, 48.5, "Gianluigi Donnarumma", weight='bold', size=12)
ax.text(6, 50.5, "PSG", weight='bold', size=12)
ax.text(2.5, 52.5, "Rating: 89", weight='bold', size=12)

# League Image Next to Title
ax_image = add_image(ligue1_image, fig, left=0.05, bottom=0.86, width=0.12, interpolation='hanning')

title = fig.suptitle("Ligue 1 Best Fantasy Team", x=0.57, y=0.93, va='center', ha='center', fontsize=50)

fig.set_facecolor(background)

# %% [markdown]
# ## Serie A Plot of best players on soccer pitch

# %%
# SETTING UP THE AXES plotting to make sure background change worked
background = 'Grey'
fig, ax = plt.subplots(figsize=(12,10))
ax.axis('off')
fig.set_facecolor(background)

# %%
# Setting up image plots
# load the image
# Ciro Immobile
image_url = 'https://i.imgur.com/hEC3Ezq.png'
immobile_image = Image.open(urlopen(image_url))
# Paulo Dybala
image_url = 'https://i.imgur.com/Qm4zEjQ.png'
dybala_image = Image.open(urlopen(image_url))
# Pedro Rodríguez Ledesma
IMAGE_URL = 'https://i.imgur.com/HHDKBdt.png'
ledesma_image = Image.open(urlopen(IMAGE_URL))
# Lorenzo Insigne
IMAGE_URL = 'https://i.imgur.com/9iBGkzU.png'
insigne_image = Image.open(urlopen(IMAGE_URL))
# Sergej Milinkovic-Savic 
IMAGE_URL = 'https://i.imgur.com/wM7gi0C.png'
savic_image = Image.open(urlopen(IMAGE_URL))
# Luis Alberto
IMAGE_URL = 'https://i.imgur.com/l4gDYcN.png'
alberto_image = Image.open(urlopen(IMAGE_URL))
# Kalidou Koulibaly
IMAGE_URL = 'https://i.imgur.com/ff5EDTk.png'
koulibaly_image = Image.open(urlopen(IMAGE_URL))
# Milan Škriniar
IMAGE_URL = 'https://i.imgur.com/VkD8uxm.png'
skriniar_image = Image.open(urlopen(IMAGE_URL))
# Giorgio Chiellini
IMAGE_URL = 'https://i.imgur.com/rIzVN81.png'
chiellini_image = Image.open(urlopen(IMAGE_URL))
# Leonardo Bonucci
IMAGE_URL = 'https://i.imgur.com/v8rjhES.png'
bonucci_image = Image.open(urlopen(IMAGE_URL))
# Wojciech Szczesny 
IMAGE_URL = 'https://i.imgur.com/xA53cLW.png'
szczesny_image = Image.open(urlopen(IMAGE_URL))
# League Image
IMAGE_URL = 'https://www.designtagebuch.de/wp-content/uploads/mediathek//2019/05/serie-a-logo.jpg'
seriea_image = Image.open(urlopen(IMAGE_URL))

# %%
#SETTING UP THE MPL AXIS FOR THE Soccer pitch
pitch = Pitch(pitch_color='grass', line_color='white', stripe=True, linewidth=3)

fig, ax = pitch.draw(figsize=(12,10))

# Strikers
ax.text(108, -1, "ST", weight='bold', size=20)
# Ciro Immobile
ax_image = add_image(immobile_image, fig, left=0.825, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(102, 60.5, "Ciro Immobile", weight='bold', size=12)
ax.text(107, 62.5, "Lazio", weight='bold', size=12)
ax.text(104, 64.5, "Rating: 87", weight='bold', size=12)

# Paulo Dybala
ax_image = add_image(dybala_image, fig, left=0.825, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(102.5, 34, "Paulo Dybala", weight='bold', size=12)
ax.text(105, 36, "Juventus", weight='bold', size=12)
ax.text(104.2, 38, "Rating: 87", weight='bold', size=12)

# Midfielders
ax.text(78, -1, "MID", weight='bold', size=20)
# Pedro Rodríguez Ledesma
ax_image = add_image(ledesma_image, fig, left=0.685, bottom=0.67, width=0.1, alpha=1, interpolation='hanning')
ax.text(77.5, 19, "Pedro Rodriguez Ledesma", weight='bold', size=12)
ax.text(88.5, 21, "Lazio", weight='bold', size=12)
ax.text(86, 23, "Rating: 86", weight='bold', size=12)

# Lorenzo Insigne
ax_image = add_image(insigne_image, fig, left=0.53, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(62.5, 34, "Lorenzo Insigne", weight='bold', size=12)
ax.text(68, 36, "Napoli", weight='bold', size=12)
ax.text(65.7, 38, "Rating: 86", weight='bold', size=12)

# Sergej Milinkovic-Savic
ax_image = add_image(savic_image, fig, left=0.53, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(58.5, 60.5, "Sergej Milinkovic-Savic", weight='bold', size=12)
ax.text(68, 62.5, "Lazio", weight='bold', size=12)
ax.text(65.3, 64.5, "Rating: 85", weight='bold', size=12)

# Luis Alberto
ax_image = add_image(alberto_image, fig, left=0.685, bottom=0.16, width=0.1, alpha=1, interpolation='hanning')
ax.text(85, 75, "Luis Alberto", weight='bold', size=12)
ax.text(88.5, 77, "Lazio", weight='bold', size=12)
ax.text(85.5, 79, "Rating: 84", weight='bold', size=12)

# Defenders
ax.text(36, -1, "DEF", weight='bold', size=20)
# Kalidou Koulibaly
ax_image = add_image(koulibaly_image, fig, left=0.37, bottom=0.67, width=0.1, alpha=1, interpolation='hanning')
ax.text(40.5, 19, "Kalidou Koulibaly", weight='bold', size=12)
ax.text(46.5, 21, "Napoli", weight='bold', size=12)
ax.text(44.5, 23, "Rating: 86", weight='bold', size=12)

# Milan Škriniar
ax_image = add_image(skriniar_image, fig, left=0.22, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(22.5, 34, "Milan Škriniar", weight='bold', size=12)
ax.text(24.3, 36, "Inter Milan", weight='bold', size=12)
ax.text(24.5, 38, "Rating: 86", weight='bold', size=12)

# Giorgio Chiellini
ax_image = add_image(chiellini_image, fig, left=0.22, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(21.3, 60.5, "Giorgio Chiellini", weight='bold', size=12)
ax.text(25.5, 62.5, "Juventus", weight='bold', size=12)
ax.text(24.5, 64.5, "Rating: 85", weight='bold', size=12)

# Leonardo Bonucci
ax_image = add_image(bonucci_image, fig, left=0.37, bottom=0.16, width=0.1, alpha=1, interpolation='hanning')
ax.text(40, 75, "Leonardo Bonucci", weight='bold', size=12)
ax.text(45, 77, "Juventus", weight='bold', size=12)
ax.text(44.1, 79, "Rating: 85", weight='bold', size=12)

# GoalKeeper
ax.text(6, -1, "GK", weight='bold', size=20)
# Wojciech Szczesny
ax_image = add_image(szczesny_image, fig, left=0.05, bottom=0.40, width=0.1, alpha=1, interpolation='hanning')
ax.text(-2.3, 48.5, "Wojciech Szczesny", weight='bold', size=12)
ax.text(3.5, 50.5, "Juventus", weight='bold', size=12)
ax.text(2.5, 52.5, "Rating: 87", weight='bold', size=12)

# League Image Next to Title
ax_image = add_image(seriea_image, fig, left=0.05, bottom=0.86, width=0.12, interpolation='hanning')

title = fig.suptitle("Serie A Best Fantasy Team", x=0.57, y=0.91, va='center', ha='center', fontsize=50)

fig.set_facecolor(background)

# %% [markdown]
# ## La Liga - Plot of best players on soccer pitch

# %%
# SETTING UP THE AXES plotting to make sure background change worked
background = 'Grey'
fig, ax = plt.subplots(figsize=(12,10))
ax.axis('off')
fig.set_facecolor(background)

# %%
# Setting up image plots
# load the image
# Luis Suarez
image_url = 'https://i.imgur.com/jCtFykg.png'
suarez_image = Image.open(urlopen(image_url))
# Sergio Aguero 
image_url = 'https://i.imgur.com/Z66a9bF.png'
aguero_image = Image.open(urlopen(image_url))
# carlos henrique venancio casimiro 
IMAGE_URL = 'https://i.imgur.com/zQLl43s.png'
casimiro_image = Image.open(urlopen(IMAGE_URL))
# toni kroos
IMAGE_URL = 'https://i.imgur.com/8Xr0UGi.png'
kroos_image = Image.open(urlopen(IMAGE_URL))
# frenkie de jong 
IMAGE_URL = 'https://i.imgur.com/F2Q9P32.png'
dejong_image = Image.open(urlopen(IMAGE_URL))
# luka modric
IMAGE_URL = 'https://i.imgur.com/uF9P4ls.png'
modric_image = Image.open(urlopen(IMAGE_URL))
# Jordi Alba Ramos
IMAGE_URL = 'https://i.imgur.com/lXbPiuM.png'
jramos_image = Image.open(urlopen(IMAGE_URL))
# Daniel Carvajal Ramos
IMAGE_URL = 'https://i.imgur.com/qte9ngc.png'
dramos_image = Image.open(urlopen(IMAGE_URL))
# Jesús Navas González
IMAGE_URL = 'https://i.imgur.com/eR1sTH4.png'
gonzalez_image = Image.open(urlopen(IMAGE_URL))
# Marcos Acuña
IMAGE_URL = 'https://i.imgur.com/xCD4oNs.png'
acuna_image = Image.open(urlopen(IMAGE_URL))
# Jan Oblak 
IMAGE_URL = 'https://i.imgur.com/q5amAkR.png'
oblak_image = Image.open(urlopen(IMAGE_URL))
# League Image
IMAGE_URL = 'https://cdn.dribbble.com/users/422205/screenshots/4025424/media/73c85cf53c36f653a484e19de3e8d180.png?compress=1&resize=400x300'
laliga_image = Image.open(urlopen(IMAGE_URL))

# %%
#SETTING UP THE MPL AXIS FOR THE Soccer pitch
pitch = Pitch(pitch_color='grass', line_color='white', stripe=True, linewidth=3)

fig, ax = pitch.draw(figsize=(12,10))

# Strikers
ax.text(108, -1, "ST", weight='bold', size=20)
# Luis Suarez
ax_image = add_image(suarez_image, fig, left=0.825, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(103.5, 60.5, "Luis Suarez", weight='bold', size=12)
ax.text(99, 62.5, "Athletico de Madrid", weight='bold', size=12)
ax.text(104, 64.5, "Rating: 88", weight='bold', size=12)

# Sergio Aguero
ax_image = add_image(aguero_image, fig, left=0.825, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(102, 34, "Sergio Aguero", weight='bold', size=12)
ax.text(104.5, 36, "Barcelona", weight='bold', size=12)
ax.text(104.2, 38, "Rating: 87", weight='bold', size=12)

# Midfielders
ax.text(78, -1, "MID", weight='bold', size=20)
# carlos henrique venancio casimiro
ax_image = add_image(casimiro_image, fig, left=0.685, bottom=0.67, width=0.1, alpha=1, interpolation='hanning')
ax.text(82.5, 19, "Carlos Casimiro", weight='bold', size=12)
ax.text(84.5, 21, "Real Madrid", weight='bold', size=12)
ax.text(85.5, 23, "Rating: 89", weight='bold', size=12)

# toni kroos
ax_image = add_image(kroos_image, fig, left=0.53, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(65.5, 34, "Toni Kroos", weight='bold', size=12)
ax.text(64.5, 36, "Real Madrid", weight='bold', size=12)
ax.text(65.7, 38, "Rating: 88", weight='bold', size=12)

# frenkie de jong
ax_image = add_image(dejong_image, fig, left=0.53, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(62.7, 60.5, "Frenkie de Jong", weight='bold', size=12)
ax.text(65.5, 62.5, "Barcelona", weight='bold', size=12)
ax.text(65.3, 64.5, "Rating: 87", weight='bold', size=12)

# luka modric
ax_image = add_image(modric_image, fig, left=0.685, bottom=0.16, width=0.1, alpha=1, interpolation='hanning')
ax.text(84.5, 75, "Luka Modric", weight='bold', size=12)
ax.text(84.5, 77, "Real Madrid", weight='bold', size=12)
ax.text(85.5, 79, "Rating: 87", weight='bold', size=12)

# Defenders
ax.text(36, -1, "DEF", weight='bold', size=20)
# Jordi Alba Ramos
ax_image = add_image(jramos_image, fig, left=0.37, bottom=0.67, width=0.1, alpha=1, interpolation='hanning')
ax.text(43.5, 19, "Jordi Ramos", weight='bold', size=12)
ax.text(44.5, 21, "Barcelona", weight='bold', size=12)
ax.text(44.5, 23, "Rating: 86", weight='bold', size=12)


# Daniel Carvajal Ramos
ax_image = add_image(dramos_image, fig, left=0.22, bottom=0.53, width=0.1, alpha=1, interpolation='hanning')
ax.text(23, 34, "Daniel Ramos", weight='bold', size=12)
ax.text(23.7, 36, "Real Madrid", weight='bold', size=12)
ax.text(24.5, 38, "Rating: 85", weight='bold', size=12)

# Jesús Navas González
ax_image = add_image(gonzalez_image, fig, left=0.22, bottom=0.29, width=0.1, alpha=1, interpolation='hanning')
ax.text(22.3, 60.5, "Jesus Gonzalez", weight='bold', size=12)
ax.text(24.7, 62.5, "Sevilla FC", weight='bold', size=12)
ax.text(24.5, 64.5, "Rating: 84", weight='bold', size=12)

# Marcos Acuña
ax_image = add_image(acuna_image, fig, left=0.37, bottom=0.16, width=0.1, alpha=1, interpolation='hanning')
ax.text(42.5, 75, "Marcos Acuna", weight='bold', size=12)
ax.text(44.5, 77, "Sevilla FC", weight='bold', size=12)
ax.text(44.1, 79, "Rating: 84", weight='bold', size=12)

# GoalKeeper
ax.text(6, -1, "GK", weight='bold', size=20)
# Jan Oblak
ax_image = add_image(oblak_image, fig, left=0.05, bottom=0.40, width=0.1, alpha=1, interpolation='hanning')
ax.text(3, 48.5, "Jan Oblak", weight='bold', size=12)
ax.text(-2.7, 50.5, "Athletico de Madrid", weight='bold', size=12)
ax.text(2.5, 52.5, "Rating: 91", weight='bold', size=12)

# League Image Next to Title
ax_image = add_image(laliga_image, fig, left=0.05, bottom=0.87, width=0.12, interpolation='hanning')

title = fig.suptitle("La Liga Best Fantasy Team", x=0.57, y=0.91, va='center', ha='center', fontsize=50)

fig.set_facecolor(background)
